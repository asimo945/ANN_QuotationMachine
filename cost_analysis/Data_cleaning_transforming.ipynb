# %%
import pandas as pd
from Data_cleaing import*

# %%
data= pd.read_excel('test_with _templet.xlsx')
clean_data=clean(data)
# Out:
# The null data from each columns are:
#
#  order quantity     0
# SPEC_1st_N         0
# SPEC_1st_L1        0
# SPEC_1st_L2        0
# SPEC_1st_L3        0
# SPEC_2nd_L1        0
# SPEC_2nd_L2        0
# SPEC_2nd_L3        0
# Customer           0
# By_way             0
# Types              0
# Ap_outer_r         0
# Ap_L               0
# cen_outter_r       0
# cen_L              0
# cen_material       0
# Shell_outer_r_1    0
# Shell_outer_r_2    0
# shell_L            0
# shell_material     0
# Human_Hrs          0
# Material_Cost      0
# dtype: int64
#
#
# The data types of each columns are:
#
#  order quantity     float32
# SPEC_1st_N         float32
# SPEC_1st_L1         object
# SPEC_1st_L2         object
# SPEC_1st_L3         object
# SPEC_2nd_L1         object
# SPEC_2nd_L2         object
# SPEC_2nd_L3         object
# Customer            object
# By_way              object
# Types               object
# Ap_outer_r         float32
# Ap_L               float32
# ...

# %%
clean_data
# Out:
#      order quantity  SPEC_1st_N SPEC_1st_L1 SPEC_1st_L2 SPEC_1st_L3  \
# 1               1.0       625.0           X           X           S
# 2               1.0       625.0           X           X           S
# 3               1.0        30.0           X           X           S
# 4               1.0       625.0           X           X           S
# 5               1.0       625.0           X           X           S
# ..              ...         ...         ...         ...         ...
# 832             2.0        40.0           A           X           S
# 833             1.0        40.0           A           X           S
# 834             1.0        40.0           A           X           S
# 835             1.0        40.0           A           X           S
# 836             1.0        40.0           A           X           S
#
#     SPEC_2nd_L1 SPEC_2nd_L2 SPEC_2nd_L3 Customer   By_way  ...   Ap_L  \
# 1             A           M           N   UMC 8C     SEMI  ...  204.0
# ...

# %%
clean_data.columns
# Out:
# Index(['order quantity', 'SPEC_1st_N', 'SPEC_1st_L1', 'SPEC_1st_L2',
#        'SPEC_1st_L3', 'SPEC_2nd_L1', 'SPEC_2nd_L2', 'SPEC_2nd_L3', 'Customer',
#        'By_way', 'Types', 'Ap_outer_r', 'Ap_L', 'cen_outter_r', 'cen_L',
#        'cen_material', 'Shell_outer_r_1', 'Shell_outer_r_2', 'shell_L',
#        'shell_material', 'Human_Hrs', 'Material_Cost'],
#       dtype='object')

# %% [markdown]
# ## export the file

# %%
clean_data.to_csv('data_train.csv')
