# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from TF_data_prepro import*

# %% [markdown]
# # **Load data**

# %%
## load data ##')
df= pd.read_csv('df_clean.csv')

# %% [markdown]
# Display Data

# %%
## show load data
pd.set_option('display.max_columns', None)
df.reset_index(inplace=True,drop=True)
df=df.drop(columns=['Unnamed: 0'])
df
# Out:
#      order quantity  price per unit Customer   By_way  Types SPEC_1st_L1  \
# 0                 1       53000.000       新唐     SEMI   國內終端           X
# 1                 1       49500.000   UMC 8C     SEMI   國內終端           X
# 2                 1       49500.000   UMC 8C     SEMI   國內終端           X
# 3                 1       59015.000     AMAT  DISPLAY  國內設備商           X
# 4                 1       49500.000   UMC 8C     SEMI   國內終端           X
# ..              ...             ...      ...      ...    ...         ...
# 778               2       80870.200     AMAT  DISPLAY  國內設備商           A
# 779               1       80870.200     AMAT  DISPLAY  國內設備商           A
# 780               1       81705.615     AMAT  DISPLAY  國內設備商           A
# 781               1       80754.150     AMAT  DISPLAY  國內設備商           A
# 782               1       80754.150     AMAT  DISPLAY  國內設備商           A
#
#     SPEC_1st_L2 SPEC_1st_L3  SPEC_1st_N  Ap_outer_r   Ap_L   AP_w  \
# 0             X           S        20.0       105.0  136.0   2.85
# 1             X           S       625.0        76.2  204.0   1.02
# 2             X           S       625.0        76.2  204.0   1.02
# 3             X           S        30.0       128.0  180.5   6.48
# 4             X           S       625.0        76.2  204.0   1.02
# ..          ...         ...         ...         ...    ...    ...
# 778           X           S        40.0       170.0  241.0  14.33
# 779           X           S        40.0       170.0  241.0  14.33
# 780           X           S        40.0       170.0  241.0  14.33
# 781           X           S        40.0       170.0  241.0  14.33
# 782           X           S        40.0       170.0  241.0  14.33
#
#      cen_outter_r  cen_L cen_material  Shell_outer_r  shell_L shell_material  \
# 0            29.0  136.0       SUS420          105.0    87.85         SUS304
# 1            44.0  204.0       SUS420           76.2    87.50         AL6061
# 2            44.0  204.0       SUS420           76.2    87.50         AL6061
# 3            54.9  180.5       SUS420          128.0   121.00         SUS304
# 4            44.0  204.0       SUS420           76.2    87.50         AL6061
# ..            ...    ...          ...            ...      ...            ...
# 778          70.0  241.0       SUS420          170.0   127.00         SUS304
# 779          70.0  241.0       SUS420          170.0   127.00         SUS304
# 780          70.0  241.0       SUS420          170.0   127.00         SUS304
# 781          70.0  241.0       SUS420          170.0   127.00         SUS304
# 782          70.0  241.0       SUS420          170.0   127.00         SUS304
#
#     SPEC_2nd_L1 SPEC_2nd_L2 SPEC_2nd_L3
# 0             W           M           R
# 1             A           M           N
# 2             A           M           N
# 3             W           M           R
# 4             A           M           N
# ..          ...         ...         ...
# 778           C           N           R
# 779           C           N           R
# 780           C           N           R
# 781           C           N           R
# 782           C           N           R
#
# [783 rows x 21 columns]

# %% [markdown]
# Split Data into Numerical and Categorical Data

# %%
all_features,num,cat=feature_col_clean_split(df)
# Out:
# /Users/linli-shang/opt/anaconda3/envs/data/lib/python3.8/site-packages/pandas/core/frame.py:4462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
num.columns
# Out:
# Index(['order quantity', 'price per unit', 'SPEC_1st_N', 'Ap_outer_r', 'Ap_L',
#        'AP_w', 'cen_outter_r', 'cen_L', 'Shell_outer_r', 'shell_L'],
#       dtype='object')

# %%
cat
# Out:
#     Customer   By_way  Types SPEC_1st_L1 SPEC_1st_L2 SPEC_1st_L3 cen_material  \
# 0         新唐     SEMI   國內終端           X           X           S       SUS420
# 1     UMC 8C     SEMI   國內終端           X           X           S       SUS420
# 2     UMC 8C     SEMI   國內終端           X           X           S       SUS420
# 3       AMAT  DISPLAY  國內設備商           X           X           S       SUS420
# 4     UMC 8C     SEMI   國內終端           X           X           S       SUS420
# ..       ...      ...    ...         ...         ...         ...          ...
# 778     AMAT  DISPLAY  國內設備商           A           X           S       SUS420
# 779     AMAT  DISPLAY  國內設備商           A           X           S       SUS420
# 780     AMAT  DISPLAY  國內設備商           A           X           S       SUS420
# 781     AMAT  DISPLAY  國內設備商           A           X           S       SUS420
# 782     AMAT  DISPLAY  國內設備商           A           X           S       SUS420
#
#     shell_material SPEC_2nd_L1 SPEC_2nd_L2 SPEC_2nd_L3
# 0           SUS304           W           M           R
# 1           AL6061           A           M           N
# 2           AL6061           A           M           N
# 3           SUS304           W           M           R
# 4           AL6061           A           M           N
# ..             ...         ...         ...         ...
# 778         SUS304           C           N           R
# 779         SUS304           C           N           R
# 780         SUS304           C           N           R
# 781         SUS304           C           N           R
# 782         SUS304           C           N           R
#
# [783 rows x 11 columns]

# %%
dummies = pd.get_dummies(cat[['Customer', 'By_way', 'Types', 'SPEC_1st_L1', 'SPEC_1st_L2',
       'SPEC_1st_L3', 'cen_material', 'shell_material', 'SPEC_2nd_L1',
       'SPEC_2nd_L2', 'SPEC_2nd_L3']],drop_first=True)

# %%
dummies.shape
# Out:
# (783, 118)

# %%
dummies.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['Customer_AUOL6A', 'Customer_AUOL7A', 'Customer_AUOL8A', 'Customer_D&E',
#        'Customer_HONJI', 'Customer_INX-2', 'Customer_INX-4', 'Customer_INX-8',
#        'Customer_INX-T1', 'Customer_KJLC',
#        ...
#        'SPEC_2nd_L1_W', 'SPEC_2nd_L2_M', 'SPEC_2nd_L2_N', 'SPEC_2nd_L2_X',
#        'SPEC_2nd_L3_H', 'SPEC_2nd_L3_N', 'SPEC_2nd_L3_R', 'SPEC_2nd_L3_U',
#        'SPEC_2nd_L3_X', 'SPEC_2nd_L3_Z'],
#       dtype='object', length=118)>

# %%
data = pd.concat([num,dummies],axis=1)
data.shape
# Out:
# (783, 128)

# %%
data.columns
# Out:
# Index(['order quantity', 'price per unit', 'SPEC_1st_N', 'Ap_outer_r', 'Ap_L',
#        'AP_w', 'cen_outter_r', 'cen_L', 'Shell_outer_r', 'shell_L',
#        ...
#        'SPEC_2nd_L1_W', 'SPEC_2nd_L2_M', 'SPEC_2nd_L2_N', 'SPEC_2nd_L2_X',
#        'SPEC_2nd_L3_H', 'SPEC_2nd_L3_N', 'SPEC_2nd_L3_R', 'SPEC_2nd_L3_U',
#        'SPEC_2nd_L3_X', 'SPEC_2nd_L3_Z'],
#       dtype='object', length=128)

# %% [markdown]
# # Set X and y

# %%
y=data['price per unit'].values
X=data.drop(['price per unit'],axis=1).values

# %% [markdown]
# # Train Test splitting

# %%
from sklearn.model_selection import train_test_split
x0_train, X_test, y0_train, y_test = train_test_split(X, y, test_size=0.2, 
                                                      random_state=101)
X_train, X_val, y_train, y_val= train_test_split(x0_train, y0_train, test_size=0.2,
                                                 random_state=101)
print(len(X_train), 'train dataset')
print(len(X_val), 'validation dataset')
print(len(X_test), 'test dataset')
# Out:
# 500 train dataset
# 126 validation dataset
# 157 test dataset

# %%
X_train.shape
# Out:
# (500, 127)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_val=scaler.fit_transform(X_val)
X_test=scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train
# Out:
# array([[0.01265823, 0.08889957, 0.0895392 , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.00168188, 0.13976851, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.08889957, 0.152304  , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.02531646, 1.        , 0.58091286, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.00360404, 0.12666521, ..., 0.        , 0.        ,
#         0.        ],
#        [0.24050633, 0.47933686, 0.20788382, ..., 0.        , 0.        ,
#         0.        ]])

# %%
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping


model=Sequential()

model.add(Dense(127,activation='relu'))
model.add(Dense(254,activation='relu'))
model.add(Dense(254,activation='relu'))
model.add(Dense(508,activation='relu'))
model.add(Dense(508,activation='relu'))
model.add(Dense(508,activation='relu'))
model.add(Dense(1016,activation='relu'))
model.add(Dense(1016,activation='relu'))
model.add(Dense(1016,activation='relu'))
model.add(Dense(2032,activation='relu'))
model.add(Dense(2032,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1016,activation='relu'))
model.add(Dense(1016,activation='relu'))
model.add(Dense(1016,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(508,activation='relu'))
model.add(Dense(508,activation='relu'))
model.add(Dense(508,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(254,activation='relu'))
model.add(Dense(254,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(127,activation='relu'))

model.add((Dense(1)))
model.compile(optimizer='adam',loss='mse')

# %%
early_stop=EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=5000)
model.fit(x=X_train,y=y_train,
          validation_data=(X_val,y_val),
          batch_size=512,
          epochs=100,
          verbose=1,
          callbacks=[early_stop]
          )
# Out:
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 41234333696.0000 - val_loss: 6315852288.0000
# Epoch 2/100
# 1/1 [==============================] - 0s 189ms/step - loss: 41234321408.0000 - val_loss: 6315151360.0000
# Epoch 3/100
# 1/1 [==============================] - 0s 189ms/step - loss: 41233580032.0000 - val_loss: 6300078080.0000
# Epoch 4/100
# 1/1 [==============================] - 0s 191ms/step - loss: 41217294336.0000 - val_loss: 6104350208.0000
# Epoch 5/100
# 1/1 [==============================] - 0s 203ms/step - loss: 41016668160.0000 - val_loss: 4528305152.0000
# Epoch 6/100
# 1/1 [==============================] - 0s 196ms/step - loss: 39325388800.0000 - val_loss: 16738396160.0000
# Epoch 7/100
# 1/1 [==============================] - 0s 193ms/step - loss: 55403126784.0000 - val_loss: 3877084928.0000
# Epoch 8/100
# 1/1 [==============================] - 0s 238ms/step - loss: 38925185024.0000 - val_loss: 5646790656.0000
# Epoch 9/100
# 1/1 [==============================] - 0s 209ms/step - loss: 40518881280.0000 - val_loss: 6143874560.0000
# Epoch 10/100
# 1/1 [==============================] - 0s 209ms/step - loss: 41059995648.0000 - val_loss: 6267641344.0000
# Epoch 11/100
# 1/1 [==============================] - 0s 187ms/step - loss: 41186193408.0000 - val_loss: 6300773888.0000
# Epoch 12/100
# 1/1 [==============================] - 0s 195ms/step - loss: 41218891776.0000 - val_loss: 6310523392.0000
# Epoch 13/100
# 1/1 [==============================] - 0s 190ms/step - loss: 41228959744.0000 - val_loss: 6313728512.0000
# Epoch 14/100
# 1/1 [==============================] - 0s 191ms/step - loss: 41231765504.0000 - val_loss: 6314892288.0000
# Epoch 15/100
# 1/1 [==============================] - 0s 190ms/step - loss: 41233252352.0000 - val_loss: 6315359232.0000
# Epoch 16/100
# 1/1 [==============================] - 0s 191ms/step - loss: 41233723392.0000 - val_loss: 6315565056.0000
# Epoch 17/100
# 1/1 [==============================] - 0s 197ms/step - loss: 41233977344.0000 - val_loss: 6315662336.0000
# Epoch 18/100
# 1/1 [==============================] - 0s
0000
# Epoch 65/100
# 1/1 [==============================] - 0s 210ms/step - loss: 13561713664.0000 - val_loss: 2888025856.0000
# Epoch 66/100
# 1/1 [==============================] - 0s 191ms/step - loss: 31751862272.0000 - val_loss: 1913441408.0000
# Epoch 67/100
# 1/1 [==============================] - 0s 205ms/step - loss: 7929712640.0000 - val_loss: 3338185728.0000
# Epoch 68/100
# 1/1 [==============================] - 0s 226ms/step - loss: 8927708160.0000 - val_loss: 3968935424.0000
# Epoch 69/100
# 1/1 [==============================] - 0s 212ms/step - loss: 18766284800.0000 - val_loss: 3916026368.0000
# Epoch 70/100
# 1/1 [==============================] - 0s 205ms/step - loss: 8251376640.0000 - val_loss: 3513700096.0000
# Epoch 71/100
# 1/1 [==============================] - 0s 209ms/step - loss: 7581533184.0000 - val_loss: 2701150720.0000
# Epoch 72/100
# 1/1 [==============================] - 0s 212ms/step - loss: 9602306048.0000 - val_loss: 2037790720.0000
# Epoch 73/100
# 1/1 [==============================] - 0s 210ms/step - loss: 6378082816.0000 - val_loss: 3505107456.0000
# Epoch 74/100
# 1/1 [==============================] - 0s 219ms/step - loss: 7696197632.0000 - val_loss: 3015329024.0000
# Epoch 75/100
# 1/1 [==============================] - 0s 194ms/step - loss: 56043429888.0000 - val_loss: 1141238912.0000
# Epoch 76/100
# 1/1 [==============================] - 0s 228ms/step - loss: 16693924864.0000 - val_loss: 1800024704.0000
# Epoch 77/100
# 1/1 [==============================] - 0s 245ms/step - loss: 25658814464.0000 - val_loss: 2267845888.0000
# Epoch 78/100
# 1/1 [==============================] - 0s 239ms/step - loss: 30568740864.0000 - val_loss: 2380352768.0000
# Epoch 79/100
# 1/1 [==============================] - 0s 214ms/step - loss: 34786193408.0000 - val_loss: 2230592512.0000
# Epoch 80/100
# 1/1 [==============================] - 0s 204ms/step - loss: 37296365568.0000 - val_loss: 1871042304.0000
# Epoch 81/100
# 1/1 [==============================] - 0s 218ms/step - loss: 37256298496.0000 - val_loss: 1340743680.0000
# Epoch 82/100
# 1/1 [==============================] - 0s 227ms/step - loss: 36506791936.0000 - val_loss: 718165760.0000
# Epoch 83/100
# 1/1 [==============================] - 0s 220ms/step - loss: 33865596928.0000 - val_loss: 310280928.0000
# Epoch 84/100
# 1/1 [==============================] - 0s 208ms/step - loss: 36371185664.0000 - val_loss: 940173888.0000
# Epoch 85/100
# 1/1 [==============================] - 0s 226ms/step - loss: 35069542400.0000 - val_loss: 2680852480.0000
# Epoch 86/100
# 1/1 [==============================] - 0s 212ms/step - loss: 34757595136.0000 - val_loss: 3271531264.0000
# Epoch 87/100
# 1/1 [==============================] - 0s 205ms/step - loss: 36558487552.0000 - val_loss: 1969071104.0000
# Epoch 88/100
# 1/1 [==============================] - 0s 193ms/step - loss: 32085731328.0000 - val_loss: 1353167488.0000
# Epoch 89/100
# 1/1 [==============================] - 0s 222ms/step - loss: 35256209408.0000 - val_loss: 1096619648.0000
# Epoch 90/100
# 1/1 [==============================] - 0s 218ms/step - loss: 29328248832.0000 - val_loss: 1541807360.0000
# Epoch 91/100
# 1/1 [==============================] - 0s 208ms/step - loss: 28736735232.0000 - val_loss: 2877447168.0000
# Epoch 92/100
# 1/1 [==============================] - 0s 251ms/step - loss: 28619517952.0000 - val_loss: 5454082048.0000
# Epoch 93/100
# 1/1 [==============================] - 0s 298ms/step - loss: 14649560064.0000 - val_loss: 11215707136.0000
# Epoch 94/100
# 1/1 [==============================] - 0s 248ms/step - loss: 17858574336.0000 - val_loss: 14627039232.0000
# Epoch 95/100
# 1/1 [==============================] - 0s 231ms/step - loss: 14329803776.0000 - val_loss: 15815191552.0000
# Epoch 96/100
# 1/1 [==============================] - 0s 231ms/step - loss: 16378899456.0000 - val_loss: 14580741120.0000
# Epoch 97/100
# 1/1 [==============================] - 0s 223ms/step - loss: 18352510976.0000 - val_loss: 3471725568.0000
# Epoch 98/100
# 1/1 [==============================] - 0s 212ms/step - loss: 10515131392.0000 - val_loss: 3793290240.0000
# Epoch 99/100
# 1/1 [==============================] - 0s 210ms/step - loss: 12254853120.0000 - val_loss: 4470645760.0000
# Epoch 100/100
# 1/1 [==============================] - 0s 198ms/step - loss: 17143783424.0000 - val_loss: 4653830144.0000

# %%
losses=pd.DataFrame(model.history.history)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,30))
losses.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
from tensorflow.keras.models import load_model
model_dir='model_NumCat_0.88.h5'
model_load=load_model(model_dir)

# %%
predictions=model_load.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 30592.61013463561

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 10215.662613201632

# %%
df['price per unit'].describe()
# Out:
# count    7.830000e+02
# mean     4.810872e+04
# std      1.614491e+05
# min      6.809600e+02
# 25%      1.060307e+04
# 50%      2.992500e+04
# 75%      4.950000e+04
# max      3.980000e+06
# Name: price per unit, dtype: float64

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.7261362600425745

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r')
plt.xlabel('Real value')
plt.ylabel('predictions')
plt.show()

# %%
import numpy as np
i=np.random.randint(len(df), size=10)
single_feedthrough=data.drop('price per unit',axis=1).iloc[i]
single_feedthrough
# Out:
#      order quantity  SPEC_1st_N  Ap_outer_r     Ap_L    AP_w  cen_outter_r  \
# 130               1        35.0       133.5  174.700   4.010         40.00
# 359               2        40.0       170.0  216.000  12.760         70.00
# 81                1       625.0        76.2  204.000   1.023         44.00
# 465               6       375.0        38.1   86.106   0.250         10.00
# 102               1        30.0       142.0  392.000  14.850         50.00
# 294               2       375.0        41.0   86.500   0.266         10.00
# 486              10        20.0       105.0  151.500   2.300         25.00
# 647              14      1500.0        75.0   90.000   1.880         50.00
# 717               4       175.0         0.0  987.500  16.940         44.45
# 441               2        40.0       170.0  241.000  14.330         70.00
#
#        cen_L  Shell_outer_r  shell_L  Customer_AUOL6A  Customer_AUOL7A  \
# 130  174.700          133.5    95.10                0                0
# 359  216.000          170.0   102.00                0                0
# 81   204.000           76.2    87.50                0                0
# 465   86.106           38.1    41.91                0                0
# 102  392.000          142.0   261.00                0                0
# 294   86.500           41.0    42.00                0                0
# 486  151.500          105.0    81.50                0                0
# 647   90.000           75.0    90.00                0                0
# 717  987.500            0.0   109.60                0                0
# 441  241.000          170.0   127.00                0                0
#
#      Customer_AUOL8A  Customer_D&E  Customer_HONJI  Customer_INX-2  \
# 130                0             0               0               0
# 359                0             0               0               0
# 81                 0             0               0               0
# 465                0             0               0               0
# 102                0             0               0               0
# 294                0             0               0               0
# 486                0             0               0               0
# 647                0             0               0               0
# 717                0             0               0               0
# 441                0             0               0               0
#
#      Customer_INX-4  Customer_INX-8  Customer_INX-T1  Customer_KJLC  \
# 130               0               0                0              0
# 359               0               0                0              0
# 81                0               0                0              0
# 465               0               0                0              1
# 102               0               0                0              0
# 294               0               0                0              0
# 486               0               0                0              1
# 647               0               0                0              0
# 717               0               0                0              0
# 441               0               0                0              0
#
#      Customer_PTW  Customer_Synergy  Customer_TSMC-8  Customer_UMC 8AB  \
# 130             0                 0                0                 0
# 359             0                 0                0                 0
# 81              0                 0                0                 0
# 465             0                 0                0                 0
# 102             0                 0                0                 0
# 294             0                 0                0                 0
# 486             0                 0                0                 0
# 647             0                 0                0                 0
# 717             0                 0                0                 0
# 441             0                 0                0                 0
#
#      Customer_UMC 8C  Customer_UMC 8S  Customer_VPC  Customer_WaferTech  \
# 130                0                0             0                   0
# 359                0                0             0                   0
# 81                 1                0             0                   0
# 465                0                0             0                   0
# 102                0                0             0                   0
# 294                0                0             0                   0
# 486                0                0             0                   0
# 647                0                0             0                   0
# 717                0                0             0                   0
# 441                0                0             0                   0
#
#      Customer_上海碩創  Customer_上銀  Customer_中研院  Customer_亞太竑  Customer_亞智  \
# 130              0            0             0             0            0
# 359              0            0             0             0            0
# 81               0            0             0             0            0
# 465              0            0             0             0            0
# 102              0            0             0             0            0
# 294              0            0             0             0            0
# 465            0              0              0            0            0
# 102            0              0              0            0            0
# 294            0              0              0            0            0
# 486            0              0              0            0            0
# 647            0              0              0            1            0
# 717            0              0              0            0            0
# 441            0              0              0            0            0
#
#      Customer_穩懋  Customer_竑新  Customer_聚昌  Customer_聚訊實業  Customer_聯穎光電  \
# 130            0            0            0              0              0
# 359            0            0            0              0              0
# 81             0            0            0              0              0
# 465            0            0            0              0              0
# 102            0            0            0              0              0
# 294            0            0            1              0              0
# 486            0            0            0              0              0
# 647            0            0            0              0              0
# 717            0            0            0              0              0
# 441            0            0            0              0              0
#
#      Customer_艾美瑞  Customer_貫旭  Customer_超延  Customer_鈦昇  Customer_鋆?  \
# 130             0            0            0            0            0
# 359             0            0            0            0            0
# 81              0            0            0            0            0
# 465             0            0            0            0            0
# 102             1            0            0            0            0
# 294             0            0            0            0            0
# 486             0            0            0            0            0
# 647             0            0            0            0            0
# 717             0            0            0            0            0
# 441             0            0            0            0            0
#
#      Customer_鴻盛  By_way_INDUSTRIAL  By_way_LED  By_way_OTHERS  By_way_PV  \
# 130            0                  0           0              0          0
# 359            0                  0           0              0          0
# 81             0                  0           0              0          0
# 465            0                  0           0              1          0
# 102            0                  0           0              0          0
# 294            0                  0           1              0          0
# 486            0                  0           0              1          0
# 647            0                  0           0              0          0
# 717            0                  0           0              0          0
# 441            0                  0           0              0          0
#
#      By_way_SEMI  Types_國內終端  Types_國內設備商  Types_國外代理商  Types_國外終端  \
# 130            1           1            0            0           0
# 359            0           0            1            0           0
# 81             1           1            0            0           0
# 465            0           0            0            1           0
# 102            0           0            0            1           0
# 294            0           0            1            0           0
# 486            0           0            0            1           0
# 647            1           0            1            0           0
# 717            0           0            1            0           0
# 441            0           0            1            0           0
#
#      Types_國外設備商  SPEC_1st_L1_B  SPEC_1st_L1_D  SPEC_1st_L1_X  SPEC_1st_L2_C  \
# 130            0              0              0              1              0
# 359            0              0              0              0              0
# 81             0              0              0              1              0
# 465            0              1              0              0              0
# 102            0              0              0              1              0
# 294            0              1              0              0              0
# 486            0              0              0              0              0
# 647            0              1              0              0              1
# 717            0              1              0              0              0
# 441            0              0              0              0              0
#
#      SPEC_1st_L2_F  SPEC_1st_L2_G  SPEC_1st_L2_K  SPEC_1st_L2_N  \
# 130              0              0              0              0
# 359              0              0              0              0
# 81               0              0              0              0
# 465              0              0              0              0
# 102              0              0              0              0
# 294              0              0              0              0
# 486              1              0              0              0
# 647              0              0              0              0
# 717              0              0              0              0
# 441              0              0              0              0
#
#      SPEC_1st_L2_S  SPEC_1st_L2_X  SPEC_1st_L3_H  SPEC_1st_L3_M  \
# 130              0              1              0              0
# 359              0              1              0              0
# 81               0              1              0              0
# 465              0              0              0              0
# 102              0              1              0              0
# 294              0              0              0              0
# 486              0              0              0              0
# 647              0              0              1              0
# 717              0              1              0              0
# 441              0              1              0              0
#
#      SPEC_1st_L3_R  SPEC_1st_L3_S  SPEC_1st_L3_X  cen_material_SUS304  \
# 130              0              1              0                    0
# 359              0              1              0                    0
# 81               0              1              0                    0
# 465              0              1              0                    0
# 102              0              1              0                    0
# 294              0              1              0                    0
# 486              0              1              0                    0
# 647              0              0              0                    0
# 717              0              1              0                    1
# 441              0              1              0                    0
#
#      cen_material_SUS420  cen_material_SUS420+SUS304  cen_material_SUS630  \
# 130                    1                           0                    0
# 359                    1                           0                    0
# 81                     1                           0                    0
# 465                    1                           0                    0
# 102                    1                           0                    0
# 294                    1                           0                    0
# 486                    1                           0                    0
# 647                    1                           0                    0
# 717                    0                           0                    0
# 441                    1                           0                    0
#
#      shell_material_SUS303  shell_material_SUS304  shell_material_SUS316  \
# 130                      0                      1                      0
# 359                      0                      1                      0
# 81                       0                      0                      0
# 465                      0                      1                      0
# 102                      0                      1                      0
# 294                      0                      1                      0
# 486                      0                      1                      0
# 647                      0                      1                      0
# 717                      0                      1                      0
# 441                      0                      1                      0
#
#      shell_material_SUS316L  SPEC_2nd_L1_C  SPEC_2nd_L1_W  SPEC_2nd_L2_M  \
# 130                       0              0              1              0
# 359                       0              0              1              0
# 81                        0              0              0              0
# 465                       0              1              0              0
# 102                       0              0              1              1
# 294                       0              1              0              0
# 486                       0              1              0              0
# 647                       0              1              0              0
# 717                       0              1              0              0
# 441                       0              1              0              0
#
#      SPEC_2nd_L2_N  SPEC_2nd_L2_X  SPEC_2nd_L3_H  SPEC_2nd_L3_N  \
# 130              1              0              0              0
# 359              1              0              0              0
# 81               1              0              1              0
# 465              1              0              0              0
# 102              0              0              0              0
# 294              1              0              0              0
# 486              1              0              0              0
# 647              1              0              0              1
# 717              1              0              0              0
# 441              1              0              0              0
#
#      SPEC_2nd_L3_R  SPEC_2nd_L3_U  SPEC_2nd_L3_X  SPEC_2nd_L3_Z
# 130              1              0              0              0
# 359              1              0              0              0
# 81               0              0              0              0
# 465              1              0              0              0
# 102              1              0              0              0
# 294              1              0              0              0
# 486              1              0              0              0
# 647              0              0              0              0
# 717              1              0              0              0
# 441              1              0              0              0

# %%
single_feedthrough=scaler.transform(single_feedthrough.values.reshape(-1,127))

# %%
model_load.predict(single_feedthrough)
# Out:
# array([[102464.836],
#        [ 92242.914],
#        [ 52838.176],
#        [  8932.995],
#        [157925.5  ],
#        [  8581.866],
#        [ 31842.623],
#        [ 37084.156],
#        [ 39509.336],
#        [ 93961.92 ]], dtype=float32)

# %%
df['price per unit'].iloc[i]
# Out:
# 130     99000.0000
# 359     80820.7470
# 81      49500.0000
# 465      9943.4025
# 102    161227.1250
# 294      8000.0000
# 486     25350.0480
# 647     34435.0000
# 717     36778.1300
# 441     83899.2000
# Name: price per unit, dtype: float64

# %%
y_test.shape
# Out:
# (157,)

# %%
errors = y_test.reshape(y_test.shape[0], 1) - predictions

# %%
import seaborn as sns
plt.figure(figsize=(12,6))
sns.distplot(errors)
plt.xlabel('Errors')
plt.show()
# Out:
# /Users/linli-shang/opt/anaconda3/envs/data/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
## model.save('model_NumCat_0.75.h5')
