# %%
import pandas as pd
from temp_to_features import *

# %%
test_dir='x_test_temp.xlsx'
x_test_feat=pd.read_excel(test_dir)
x_test_feat
# Out:
#    數量               規格      客戶       通路     型態  外觀外徑(mm)  外觀長度(mm)  重量(kg)  \
# 0   １  AXS0035CKR00001      新唐     SEMI   國內終端      2.85      2.85   2.850
# 1   5  XXS0030WMR00004  AUOL8A  DISPLAY   國內終端    138.00    231.00   8.600
# 2   5  XXS0030WMR00004  AUOL8A  DISPLAY   國內終端    138.00    231.00   8.600
# 3   5  XXS0012CNR00001      崇文     SEMI  國內設備商     56.00    103.20   0.492
# 4   1  XXS0625AMN00002  UMC 8C     SEMI   國內終端     76.20    204.00   1.020
# 5   1  XXS0625AMN00001  UMC 8C     SEMI   國內終端     76.20    204.00   1.020
# 6   1  XFS0020WNR00002      貫旭   OTHERS  國內設備商    105.00    242.00   2.230
# 7   1  XXS0030WMR00006    AMAT  DISPLAY  國內設備商    138.00    231.00  11.000
# 8   1  XXS0030WMR00006    AMAT  DISPLAY  國內設備商    138.00    231.00  11.000
# 9   1  XXS0625AMN00002  UMC 8C     SEMI   國內終端     76.20    204.00   1.020
# 10  1  XXS0625AMN00001  UMC 8C     SEMI   國內終端     76.20    204.00   1.020
# ...

# %%
data_frame_cleaned=temp_to_features(x_test_feat)
data_frame_cleaned
# Out:
# order quantity    0
# Customer          0
# By_way            0
# Types             0
# SPEC_1st_L1       0
# SPEC_1st_L2       0
# SPEC_1st_L3       0
# SPEC_1st_N        0
# Ap_outer_r        0
# Ap_L              0
# AP_w              0
# cen_outter_r      0
# cen_L             0
# cen_material      0
# Shell_outer_r     0
# shell_L           0
# shell_material    0
# SPEC_2nd_L1       0
# SPEC_2nd_L2       0
# SPEC_2nd_L3       0
# dtype: int64
# order quantity    float32
# Customer           object
# By_way             object
# Types              object
# SPEC_1st_L1        object
# SPEC_1st_L2        object
# SPEC_1st_L3        object
# SPEC_1st_N        float32
# Ap_outer_r        float32
# Ap_L              float32
# AP_w              float32
# cen_outter_r      float32
# cen_L             float32
# cen_material       object
# Shell_outer_r     float32
# shell_L           float32
# shell_material     object
# SPEC_2nd_L1        object
# SPEC_2nd_L2        object
# ...

# %%
data_frame_cleaned.to_excel('df_to_pred.xlsx',
             sheet_name='data_frame_cleaned')
